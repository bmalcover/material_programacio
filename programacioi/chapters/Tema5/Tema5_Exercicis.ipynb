# %% [markdown]
# ## Exercicis Tema 5
#
# ### Llistes
#
# #### Introducció a les llistes
#
# 1.Donada la següent llista, realitza les operacions que hi ha a continuació i verifica  la seva correctessa després
# de l'execució `la_meva_llista = [1,2,3,4,5,6,7]`
#
#     1. Cambia el primer valor per 33.
#
#     2. Mostra la seva longitud per pantalla.
#
#     3. Mostra els 3 últims valors.
#
#     4. Cambia el valor central per el valor -5.
#
#     5. Afegeix la llista [8, 9, 10] a la_meva_llista.
#
#     6. Elimina el valor 3.
#
#     7. Verifica que ja no existeix el valor 4.
#
#     8. Inserta el valor 10 després del valor 2.
#
# 2.Crear un programa que guarda en una llista de 10 elements la posició que ocupa cada element i després el mostri per pantalla. Es a dir, hem de guardar a l'índex 0, el valor 1 fins arribar a l'índex 9, el valor 10.
#
# 3.Copia el següent codi que crearà una llista amb DNIS, mostra per pantalla aquells que es troben en posicions amb
# índex parell `dni = [43542311, 43542312,43542313, 43542314, 43542315, 43542316]`.
#
# #### Llistes i seqüències
#
# 4.Crear un programa que llegeig una seqüència de caràcters acabada en punt, la guarda en una llista i després mostra la seqüència invertida.
#
# 5.Elimina totes les ocurrències del valor 2 en la següent llista: `segona_llista = [1,2,2,4,5,2,4,2,2]`. Volem modificar la llista anomenada `segona_llista` no crear-ne una de nova.
#
# 6.Crear un programa que generi 10 nombres aleatoris en l'interval `[0, 100]` i els guardi en una llista. Posteriorment ha de crear una nova llista amb els números menors a 50 i mostrar-la per pantalla.
#
# 7.Crear una funció que rebi una llista amb valors numèrics i retorni **una nova** llista on cada posició té la suma acumulada dels valors anteriors amb el valor d'aquesta posició.
#
# 8.Crear un programa que llegeix una seqüència acabada en punt i ens digui la freqüència d'aparició de cada vocal. És obligatori l'ús de llistes.
#
# 9.Crear un programa que genera 60 nombres aleatoris en l'interval `[0, 100]` i els guarda en una llista. Posteriorment heu de generar una **nova llista** sense duplicats.
#
# 10.Crear un programa que llegeix dues seqüències de la mateixa longitud acabades en punt, i mostra per pantalla el resultat d'intercalar les dues seqüències. La introducció de les dues seqüències s'ha de fer en una sola línia.
# ```
#     Per exemple:
#
#     hola cargol de mar.adeu juanito.
#
#     combinació:
#
#     haodliao sc ajruaacnoiltao
# ```
#
# Versió més difícil: Realitzar el mateix exercici llegint cada seqüència en diferents línies i permetent que les dues seqüències siguin de diferent longitud.
#
# 11.Crear un programa que llegeix una seqüència de paraules acabades en punt. El tractament de cada paraula consisteix a emmagatzemar-la en una llista i determinar si la paraula és un palíndrom (capicua). Vegeu el següent exemple:
#
# ```
#     avio rallar.
#     avio.    no és capicua
#     rallar. és capicua
#
# ```
#
# 12.Crear un programa que genera dues llistes de longitud 10 amb nombres aleatoris en l'interval 0-20, les mostra i posteriorment mostra la llista resultant de realitzar l'intersecció entre les dues. **Recordatori:** l'operand `in` permet saber si un valor està en una llista, tornant un booleà.
#
# 13.Crear un programa que guarda en una llista que només conté valors booleans si el nombre en qüestió és primer o
# no. Ho ha de calcular pels números del 0 al 100. Finalment hem de veure el següent per pantalla:
#
# ```
#     0 -> fals
#
#     1 -> fals
#
#     2 -> cert
#
#     3 -> cert
#
#     4 -> fals
#
#     5 -> cert
#
#     6 -> fals
#
#     7 -> cert
#     ...
#
#     99 -> fals
#     100 -> fals
# ```
#
# 14.Crear un programa que ens mostri els nombres primers menors a 100 usant el mètode del filtre d'Eratòstenes.
# [Explicacio](https://es.wikipedia.org/wiki/Criba_de_Erat%C3%B3stenes)
#
# 15.Crear un programa que calculi els *n* primers valors de la sèrie de
# Fibonacci i els guardi en una llista, després ha de recórrer la llista i imprimir els valors. El valor *n* ha de
# demanar-se a l'usuari)
#
# La sèrie de Fibonacci es defineix com $f(n) = f(n-1) + f(n-2)$. i els primers dos termes són igual a 1.
#
#
# 16.Modificar el programa perquè també mostri l'aproximació al nombre auri. El nombre auri es pot aproximar mitjançant la relació de dos nombres consecutius de la sèrie de Fibonacci. El programa ha de fer l'aproximació amb el valor `n` i el valor `n-1`:
#
# ```
#     3/2 = 1.5
#     5/3 = 1.66666
#     8/5 = 1.6
#     13/8 = 1.625
#     21/13 = 1.61538461
#     34/21 = 1.6190476
#     55/34 = 1.61764705
# ```
# ### Strings
#
# Aquests exercicis están dissenyats per practicar només amb _Strings_. Podeu emprar tots els mètodes existents.
#
# 17.Donat un _String_ llegit per teclat, elimina tots els caràcters excepte els nombres enters.
# Exemple: `str1 = "Tinc 25 anys i 10 mesos"` llavors `str = "2510`
#
# 18.Donats dos _Strings_, `s1` i `s2`. Escriu un programa per crear un nou _String_ anomenat s3 que és el resultat d'inserir `s2` al mig de _s1_. Si la longitut de s1 és senar, la part més llarga quedarà al principi.
#
# Exemple: `s1 = "joan"` i `s2=patata` llavors `s3=jopatataan`.
#
# 19.Escriu una funció anomenada `digits` que rep un _String_, `s1`, que retorna la suma dels dígits que apareixen a `s1`, ignorant tots els altres caràcters. Recorda que en aquests exercicis només pots emprar mètodes relacionats amb _Strings_.
#
# 20.Escriu un programa per trobar paraules que contenen lletres de l'alfabet i números (ambdues coses) a partir d'un _String_ d'entrada.
#
# Exemple: `str1 = "Emma25 is 50scientist and AI Expert"`  llavors ha de mostrar `Emma25` i `50scientist`.
#
#
# ### Orientació a objecte
#
# Exercicis introducció classes i objectes
#
# #### Classe NumeroRacional
#
# Crear una classe anomenada NumeroRacional que ens permet crear programes amb variables de tipus nombre racional. Un
# nombre racional és un nombre que s'expressa com el quocient de 2 nombres sencers, p.e. 5/2.
#
# Abans de començar a programar, recomano que llegiu tots els punts de l'exercici, ja que us pot permetre entendre
# millor la funcionalitat de la classe.
#
# Aquesta classe, té dos atributs, un dividend i un divisor.
#
# 1. Implementar el constructor, que rep els valors que tindran el dividend i el divisor.
# 2. El mètode **simplificar_quocient**, un procediment que no rep paràmetres i divideix el dividend i el divisor pel _mcd_
# dels dos. Per exemple, si els valors són 54 i 10, els simplifica a 27 i 5.
# 3. Un mètode **es_infinit** que retorni un booleà indicant si el nombre és infinit, és a dir si el divisor és zero.
# 4. Implementar un mètode **obtenir_quocient**, una funció que ens retorna el quocient del nombre racional.
# 5. Implementar un mètode **suma**, una funció que rep un nombre racional per paràmetre i retorna un nou número racional
# resultat de sumar el nombre racional amb el que rebem per paràmetre: La suma a / b + c / d, és (a * d + c * b) / (b * d).
# 6. implementar el mètode **str**, d'aquesta forma al fer print d'una variable de tipus nombre racional ho mostri per
# consola.
#
# Les classes que es troben en altres fitxers es poden importar d'igual manera que els subprogrames, tal com hem vist al taller.
#
# Un cop realitzada la classe NumeroRacional, heu implementar dos programes.
#
# 1. Programa que construeix un nombre racional a partir de la lectura de dos valors que l'usuari escriu pel teclat. Si
# el nombre racional no és infinit, sumar el nombre 3/4. Finalment heu de simplificar el nombre resultant i mostrar per
# pantalla.
# 2. Realitzar un programa que calculi la següent aproximació al quadrat del nombre pi amb 1000 termes de la
# seqüència. Heu de fer-ho en termes de nombres racionals i mostrar el resultat final per pantalla, en format decimal.
# 6 (1/1 + 1/4 + 1/9 + 1/16 + 1/25 ... ..)
#
#
# En posteriors exercicis ampliarem aquesta classe amb més funcionalitats.
#
# #### Classe punt 3D
#
# Crear una classe anomenada Punt que ens permet crear programes amb variables de el tipus punt. Un punt és una
# localització en l'espai 3D que s'expressa com 3 valors referents a les coordenades x, i, z. Per exemple (1, 0, 4).
#
# Abans de començar a programar, recomano que llegiu tots els punts de l'exercici, ja que us pot permetre entendre
# millor la funcionalitat de la classe.
#
# Quants atributs ha de tenir aquesta classe?
#
# 1. El constructor rep un valor per a cada atribut.
# 2. implementar un mètode **origen**, que retorna `True` si el punt es troba en l'origen de coordenades i `False` en cas
# contrari.
# 3. implementar un mètode **distancia** que rep un punt per paràmetre i ens retorna la distància entre el nostre punt,
# `self` , i el punt rebut per paràmetre.
# 4. implementar el mètode **str**.
#
# Implementar un programa principal que generi dos punts de manera aleatòria, les coordenades es poden generar entre
# els valors [-10, 10], mostreu els valors dels dos punts per pantalla. Comproveu que la distància del primer punt al
# segon és la mateixa que la distància del segon punt al primer, mostrar per pantalla.
#
# En posteriors exercicis ampliarem aquesta classe amb més funcionalitats.
#
#
#
# A continuació tenim tres exercicis dissenyats per practicar l'implementació de classes, en concret els conceptes
# d'encapsulació i mètodes de classe. No tenen cap programa principal associat però s'espera que a mesura que
# implementeu els diferents mètodes els proveu per assegurar-ne un correcte funcionament.
#
# #### Classe Data
#
# Crear un tipus de dades data, mitjançant la implementació d'una classe que guardarà el dia, mes (com un nombre) i any.
#
# 1. Té un constructor que rep: dia, mes i any.
# 2. Implementar un mètode de classe, **son_iguals**, que rep dues dates i retorna un booleà indicant si aquestes són
# iguals.
# 3. Implementar un mètode de classe, **es_major**, que rep dues dates i retorna un booleà indicant si la primera és
# més gran que la segona.
# 4. Implementar un mètode de classe, **es_menor**, que rep dues dates i retorna un booleà indicant si la primera és
# menor que la segona.
# 5. Fer un mètode, **dies_mes**, que donat un mes i un any retorna el nombre de dies del mes. Cal recordar que els anys de
# traspàs febrer té 29 dies.
# 6. Fer un mètode privat, anomenat **es_any_traspas**, que donat un nombre enter i retorni un booleà indicant si és de
# traspàs o no. Un any és de traspàs si és divisible per 4, però no és de traspàs si és divisible per 100 i no per 400. Per
# exemple 1996 és de traspàs, 2000 si (és divisible per 400) i 2100 no (és divisible per 100 i no per 400).
#
# 7. Incorporar un mètode, **es_traspas**, que indiqui si la data està en any de traspàs, s'ha de fer ús de el mètode
# anterior.
# 8. Implementar un mètode anomenat **incrementa** que incrementi en un dia la data, tenint en compte que si sobrepassem
# l'últim dia del mes hem d'incrementar el mes, i hem de fer el mateix raonament per a l'últim mes de l'any.
# 9. Implementar un mètode de classe anomenat **diferència** que donades dues dates ens digui el nombre de dies entre les
# dues dates (podeu utilitzar aquest mètode per saber quants dies heu viscut ;) ).
#
#
#
# #### Classe Vector
#
# Anem a fer l'exercici classe vector. En aquest cas heu de implementar la classe (definir atributs i mètodes) i
# realitzar un programa principal que permeti comprovar el seu correcte funcionament (no cal fer entrada per teclat).
#
# Per definir un vector 3 dimensional: són necessaris 3 sencers (x, i, z). Recordeu que els atributs han de ser privats.
#
# Operacions:
#
# 1. Crear un vector en una posició determinada (constructor).
# 2. Implementar el mètode **mòdul** que ens retorna el mòdul del vector en format numèric.
# 3. Mètode suma: mètode de classe que rep dos vectors per paràmetre realitza l'operació **suma**. Es sumen les
# components, i ens retorna un nou Vector.
# 4. Mètode resta: mètode de classe que rep dosectors per paràmetre i realitza l'operació **resta**. Retorna un nou
# vector.
# 5. Mètode que rep un vector i realitza el seu **producte_escalar** retornant el seu valor numèric.
# 6. Mètode **mult_escalar** que multiplica les tres components del vector per un escalar rebut per paràmetre.
# 7. Mètode **str** que retorna un string que conté les tres components del vector.
# 8. Mètode anomenat **son_iguals** que rep un vector per paràmetre i retorna una variable booleana si les
# tres components dels vectors son iguals.
# 9. Mètode **calcular_angle**: calcula l'angle amb un altre vector que rep per paràmetre i retorna valor de l'angle
# entre ells. Link: Angle de dos vectors
#
# #### Ampliació Classe Punt
#
# Modificar la classe Punt realitzada anteriorment. En primer lloc, heu de transformar els atributs en atributs privats
#  i afegir les següents operacions. Com veureu aquestes necessiten de les operacions de vectors, per tant també necessitem fer el import de la classe Vector a la classe punt:
#
# 1. Implementar l'operació **resta**, aquest és un mètode de classe que retorna el Vector resultat de la resta de dos
# punts.
# 2. Implementar l'operació **suma**, a un punt li suma un Vector rebut per paràmetre. Retorna un nou punt.
# 3. Operació **suma_escalar**, rep un vector i un enter per paràmetre. Suma el Vector que es multiplica per l'escalar
# rebut i retorna un nou Punt: $P$ = $P + a ·\vec{v}$
#
# Com podeu observar ens cal fer l'operació suma entre un punt i un vector en dos mètodes diferents. Per poder
# reutilitzar el codi entre aquests dos mètodes es demana que implementar un mètode privat anomenat **suma_interna** que
# realitza aquest procés i que pugui ser usat per les operacions **suma** i **suma_escalar**.
#
# #### Classe Compte Corrent
#
# En aquest exercici s'ha d'implementar la classe es a dir definir els atributs i implementar els mètodes. També es
# demana realitzar un programa principal on comproveu el seu correcte funcionament. No cal fer entrada per teclat.
#
# Un compte corrent ha de tenir informació referent a l'saldo i a l'interès aplicat a aquest compte, els dos valors han
# de permetre guardar xifres decimals. A més s'ens sol·licita poder realitzar les següents operacions:
#
# El constructor ha de permetre crear un compte corrent amb un saldo inicial i un interès definit per l'usuari. Per
# defecte el saldo ha de ser de 100 € i l'interès del 5%.
#
# S'han d'implementar els següents mètodes:
#
# 1. Mètode **suma** al que el saldo és incrementat en x €.
# 2. Mètode **resta** en què el saldo és decrementat en x €, s'ha de tenir en compte que no és possible tenir un saldo
# negatiu. Si en cridar a aquesta operació ens adonam que no és pot aplicar, s'ha de mostrar un  missatge d'error per
# pantalla i evidentment no s'ha de l'operació realitzar.
# 3. Mètode **abonament_interes** que ha d'incrementar el saldo en funció de l'interès que s'aplica al compte.
# 4. Funció **obtenir_saldo**, que permet conèixer el saldo actual del compte.
# 5. Mètode **modificar_interes** que modifica l'interès del compte.
# 6. Una funció transferència que ha de permetre realitzar una transferència de x€ a un altre compte que rebem per
# paràmetre, sempre que això sigui possible.
#
# #### Classe Àlbum de Cromos
#
# Aquesta classe d'emmagatzemar permetre gestionar una col·lecció de cromos. Un objecte d'aquesta classe ha de contenir
# els números de cromos que posseïm i totes les vegades que el tenim repetit. En aquest cas a l'enunciat es  proporcionen les definicions dels mètodes i els seus paràmetres
#
# 1. Crear un *constructor* que rep un enter, el nombre cromos de què consta l'àlbum.
# 2. Crear el mètode **get_maxim_cromos()**, que retorna el màxim nombre de cromos que pot tenir un àlbum.
# 2. Crear un mètode **rebre_cromo(num_cromo)** indica que hem aconseguit el cromo amb el número rebut.
# 3. Crear un mètode **donar_cromo(num_cromo)** indica que ens hem desfet d'un cromo amb aquest nombre.
# 4. Crear un mètode **get_num_cromos()** retorna quants cromos diferents tenim (sense comptar repetits).
# 5. Crear un mètode **get_num_cromos_repetits()**, retorna el total de cromos que tenim comptant els cromos repetits.
# 6. Crear un mètode **get_num_cromos_faltants()** retorna quants cromos ens falta per tenir la col·lecció completa.
# 7. Crear el mètode **mostrar_repetits()**, mostra per pantalla els cromos repetits i el nombre de vegades que el tenim
# repetit.
# 8. Crear el mètode **mostrar_cromo_mes_repetit()** mostra el o els números dels cromos més repetits
# 9. Crear els mètodes que permeten comparar 2 àlbums en funció del nombre de cromos que ens falten.
#
# **Programa principal**
#
# A continuació teniu un exemple d'un programa principal que fa servir aquesta classe, comprovau el correcte
# funcionament de la classe implementada executant aquest codi.
#
# ```
# dragon_ball = AlbumCromos (120)
#
# dragon_ball.rebre_cromo(1) #Consegueixo el cromo número 1 de l'àlbum
# dragon_ball.rebre_cromo(120) #Consegueixo el darrer cromo de l'àlbum
# dragon_ball.rebre_cromo(120) #Cromo repetit
# dragon_ball.rebre_cromo(75)
# dragon_ball.rebre_cromo(76)
# dragon_ball.rebre_cromo(76) #Consigo el 76
# dragon_ball.rebre_cromo (75) #Consigo el 75
# dragon_ball.donar_cromo (120) #Em quedo amb un sol crom nombre 120
#
# print(dragon_ball.get_num_cromos_faltants())
# dragon_ball.mostrar_repetits()
# dragon_ball.mostrar_cromo_mes_repetit()
# ```
